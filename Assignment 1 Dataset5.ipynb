# %% [markdown]
# # Dataset 5 - Focusing on SOFA respiration
#
# ### To explore on the feature 'sofa_respiration'
# ### The entire workbook did not complete running before the submission, leading to missing results.

# %% [markdown]
# ## Data Processing

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'Assignment_1_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36489 entries, 0 to 36488
# Data columns (total 60 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   gender                      36489 non-null  object
#  1   age                         36489 non-null  float64
#  2   heart_rate_min              36417 non-null  float64
#  3   heart_rate_max              36417 non-null  float64
#  4   heart_rate_mean             36417 non-null  float64
#  5   mbp_min                     36401 non-null  float64
#  6   mbp_max                     36401 non-null  float64
#  7   mbp_mean                    36401 non-null  float64
#  8   sbp_min                     36343 non-null  float64
#  9   sbp_max                     36343 non-null  float64
#  10  sbp_mean                    36343 non-null  float64
#  11  dbp_min                     36341 non-null  float64
#  12  dbp_max                     36341 non-null  float64
#  13  dbp_mean                    36341 non-null  float64
#  14  temperature_min             36126 non-null  float64
#  15  temperature_max             36126 non-null  float64
#  16  temperature_mean            36126 non-null  float64
#  17  lactate_min                 15930 non-null  float64
#  18  lactate_max                 15930 non-null  float64
#  19  ph_min                      18860 non-null  float64
#  20  ph_max                      18860 non-null  float64
#  21  chloride_min                6129 non-null   float64
#  22  chloride_max                6129 non-null   float64
#  23  calcium_min                 9289 non-null   float64
#  24  calcium_max                 9289 non-null   float64
#  25  sodium_min                  6554 non-null   float64
#  26  sodium_max                  6554 non-null   float64
#  27  glucose_min                 36191 non-null  float64
#  28  glucose_max                 36191 non-null  float64
#  29  wbc_min                     36235 non-null  float64
#  30  wbc_max                     36235 non-null  float64
#  31  creatinine_min              36291 non-null  float64
#  32  creatinine_max              36291 non-null  float64
#  33  hemoglobin_min              36232 non-null  float64
#  34  hemoglobin_max              36232 non-null  float64
#  35  total_protein_max           974 non-null    float64
#  36  total_protein_min           974 non-null    float64
#  37  pt_min                      32345 non-null  float64
#  38  pt_max                      32345 non-null  float64
#  39  alt_max                     18663 non-null  float64
#  40  alt_min                     18663 non-null  float64
#  41  alp_max                     18580 non-null  float64
#  42  alp_min                     18580 non-null  float64
#  43  ast_min                     18776 non-null  float64
#  44  ast_max                     18776 non-null  float64
#  45  bilirubin_total_max         18590 non-null  float64
#  46  bilirubin_total_min         18590 non-null  float64
#  47  bilirubin_direct_max        1605 non-null   float64
#  48  bilirubin_direct_min        1605 non-null   float64
#  49  bilirubin_indirect_max      1544 non-null   float64
#  50  bilirubin_indirect_min      1544 non-null   float64
#  51  urineoutput                 35073 non-null  float64
#  52  sofa_respiration            7587 non-null   float64
#  53  sofa_coagulation            36235 non-null  float64
#  54  sofa_liver                  18590 non-null  float64
#  55  sofa_cardiovascular         36402 non-null  float64
#  56  sofa_cns                    36468 non-null  float64
#  57  sofa_renal                  36467 non-null  float64
#  58  charlson_comorbidity_index  36489 non-null  int64
#  59  outcome                     36489 non-null  bool
# dtypes: bool(1), float64(57), int64(1), object(1)
# memory usage: 16.5+ MB

# %%
df.head(10)
# Out:
#   gender        age  heart_rate_min  heart_rate_max  heart_rate_mean  mbp_min  \
# 0      M  54.550390            93.0           115.0       103.500000     57.0
# 1      M  86.324653            50.0            61.0        54.333333     61.0
# 2      M  40.270146            70.0           105.0        83.434783     66.0
# 3      M  73.383547            68.0            98.0        83.880000     74.0
# 4      M  70.724748            77.0            95.0        85.771429     30.0
# 5      F  24.131524            82.0           111.0        95.640000     53.0
# 6      M  68.308897            60.0            80.0        71.083333     63.0
# 7      F  57.433933            62.0            92.0        75.240000     65.0
# 8      M  62.564975            48.0            87.0        59.000000     56.0
# 9      M  66.238225            61.0            80.0        69.750000     61.0
#
#    mbp_max   mbp_mean  sbp_min  sbp_max  ...  bilirubin_indirect_min  \
# 0    100.0  82.733333     87.0    163.0  ...                     NaN
# 1     93.0  71.695652     95.0    141.0  ...                     NaN
# 2     92.0  76.695652     94.0    129.0  ...                     NaN
# 3    101.0  84.694444     83.0    148.0  ...                     NaN
# 4     90.0  62.657143     52.0    129.0  ...                     NaN
# 5    113.0  77.520000     86.0    136.0  ...                     NaN
# 6    112.0  75.720000     87.0    153.0  ...                     NaN
# 7     97.0  78.160000     88.0    125.0  ...                     NaN
# 8     86.0  71.954545    104.0    140.0  ...                     NaN
# 9     92.0  74.958333     93.0    127.0  ...                     NaN
#
#    urineoutput  sofa_respiration  sofa_coagulation  sofa_liver  \
# 0       3459.0               2.0               0.0         NaN
# 1       2020.0               NaN               1.0         NaN
# 2       3050.0               NaN               1.0         0.0
# 3       1592.0               NaN               0.0         NaN
# 4        339.0               2.0               0.0         0.0
# 5       6000.0               NaN               0.0         NaN
# 6       2560.0               1.0               1.0         NaN
# 7       2200.0               NaN               2.0         0.0
# 8        800.0               NaN               1.0         NaN
# 9       1925.0               NaN               0.0         NaN
#
#    sofa_cardiovascular  sofa_cns  sofa_renal  charlson_comorbidity_index  \
# 0                  1.0       0.0         1.0                           3
# 1                  1.0       1.0         1.0                           8
# 2                  1.0       1.0         0.0                           4
# 3                  0.0       0.0         1.0                           6
# 4                  4.0       1.0         3.0                          10
# 5                  1.0       0.0         0.0                           1
# 6                  1.0       1.0         0.0                           3
# 7                  3.0       0.0         0.0                           4
# 8                  1.0       0.0         0.0                           4
# 9                  1.0       0.0         2.0                           7
#
#    outcome
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
#
# [10 rows x 60 columns]

# %%
df['outcome'].value_counts(normalize=True)
# Out:
# False    0.963578
# True     0.036422
# Name: outcome, dtype: float64

# %%
df['gender'].replace({'M':1, 'F':0}, inplace=True)

# %%
df_norm = df.copy()
for col in df_norm:
    if df_norm[col].dtype == 'float64' or df_norm[col].dtype == 'int64':
        df_norm[col] = (df_norm[col] - df_norm[col].mean())/df_norm[col].std()

# %%
df_norm.describe().transpose()
# Out:
#                               count          mean  std        min       25%  \
# gender                      36489.0  3.875086e-17  1.0  -1.094033 -1.094033
# age                         36489.0 -5.140817e-17  1.0  -2.851891 -0.616634
# heart_rate_min              36417.0 -3.476912e-16  1.0  -4.111428 -0.725898
# heart_rate_max              36417.0  7.804517e-18  1.0  -3.244683 -0.730533
# heart_rate_mean             36417.0 -1.841866e-16  1.0  -3.527194 -0.721902
# mbp_min                     36401.0 -3.853222e-16  1.0  -4.465290 -0.556648
# mbp_max                     36401.0  5.953560e-16  1.0  -2.333690 -0.620407
# mbp_mean                    36401.0 -5.176669e-16  1.0  -3.124648 -0.710890
# sbp_min                     36343.0  4.467408e-16  1.0  -5.534193 -0.655478
# sbp_max                     36343.0 -4.107669e-16  1.0  -4.318088 -0.686553
# sbp_mean                    36343.0  2.091959e-16  1.0  -4.631456 -0.735232
# dbp_min                     36341.0  2.934770e-16  1.0  -3.912645 -0.622571
# dbp_max                     36341.0 -3.386423e-16  1.0  -3.041425 -0.712823
# dbp_mean                    36341.0 -1.167456e-15  1.0  -3.047606 -0.702753
# temperature_min             36126.0  4.833327e-15  1.0 -26.160605 -0.324708
# temperature_max             36126.0 -3.851084e-15  1.0  -6.263012 -0.572327
# temperature_mean            36126.0  5.866314e-15  1.0  -8.689622 -0.508974
# lactate_min                 15930.0 -1.371575e-16  1.0  -1.591127 -0.621222
# lactate_max                 15930.0 -7.582691e-17  1.0  -1.267199 -0.621969
# ph_min                      18860.0 -3.254708e-15  1.0  -7.220305 -0.513176
# ph_max                      18860.0  3.295773e-15  1.0  -8.493592 -0.663619
# chloride_min                 6129.0 -1.572028e-15  1.0 -16.600030 -0.372952
# chloride_max                 6129.0  1.136126e-16  1.0 -16.394583 -0.380960
# calcium_min                  9289.0 -8.528961e-16  1.0  -7.036731 -0.470260
# calcium_max                  9289.0 -9.186800e-16  1.0  -4.407540 -0.628065
# sodium_min                   6554.0  9.842600e-16  1.0 -22.508336 -0.303575
# sodium_max                   6554.0 -1.458163e-16  1.0 -22.768733 -0.281957
# glucose_min                 36191.0  3.691029e-17  1.0  -2.771871 -0.617769
# glucose_max                 36191.0 -3.514331e-17  1.0  -1.416492 -0.479956
# wbc_min                     36235.0 -5.882788e-18  1.0  -1.293742 -0.459571
# wbc_max                     36235.0  3.019831e-17  1.0  -1.177125 -0.437234
# creatinine_min              36291.0  1.251100e-16  1.0  -0.838861 -0.429778
# creatinine_max              36291.0 -3.798333e-17  1.0  -0.807439 -0.428532
# hemoglobin_min              36232.0  1.911084e-16  1.0  -3.549387 -0.742604
# hemoglobin_max              36232.0  3.970230e-16  1.0  -3.541217 -0.733299
# total_protein_max             974.0 -6.428807e-17  1.0  -3.774726 -0.599058
# total_protein_min             974.0 -3.994067e-16  1.0  -3.868268 -0.594358
# pt_min                      32345.0  2.653689e-16  1.0  -1.047363 -0.459184
# pt_max                      32345.0 -2.005644e-16  1.0  -0.805555 -0.423386
# alt_max                     18663.0  4.568672e-18  1.0  -0.153995 -0.136285
# alt_min                     18663.0  1.142168e-18  1.0  -0.209631 -0.174219
# alp_max                     18580.0  2.982903e-17  1.0  -0.872099 -0.442227
# alp_min                     18580.0  8.604527e-18  1.0  -0.907795 -0.446541
# ast_min                     18776.0 -1.892157e-19  1.0  -0.215362 -0.176256
# ast_max                     18776.0 -2.459804e-18  1.0  -0.176130 -0.155011
# bilirubin_total_max         18590.0  4.968830e-18  1.0  -0.391728 -0.318551
# bilirubin_total_min         18590.0  5.580379e-17  1.0  -0.376003 -0.295179
# bilirubin_direct_max         1605.0  7.193969e-18  1.0  -0.621411 -0.527061
# bilirubin_direct_min         1605.0  1.106764e-16  1.0  -0.609329 -0.531056
# bilirubin_indirect_max       1544.0  3.566520e-17  1.0  -0.765513 -0.591126
# bilirubin_indirect_min       1544.0 -7.794571e-17  1.0  -0.739902 -0.559676
# urineoutput                 35073.0  9.501455e-17  1.0 -13.233208 -0.682769
# sofa_respiration             7587.0  4.588980e-17  1.0  -2.929216  0.469463
# sofa_coagulation            36235.0  2.451162e-17  1.0  -0.583139 -0.583139
# sofa_liver                  18590.0  4.968830e-17  1.0  -0.533429 -0.533429
# sofa_cardiovascular         36402.0 -5.270220e-18  1.0  -1.090354 -0.062088
# sofa_cns                    36468.0  5.981590e-17  1.0  -0.871209 -0.871209
# sofa_renal                  36467.0  1.558763e-18  1.0  -0.687885 -0.687885
# charlson_comorbidity_index  36489.0  4.284014e-17  1.0  -1.923221 -0.596428
#
#                                  50%       75%        max
# gender                      0.914024  0.914024   0.914024
# age                         0.091196  0.763350   2.200235
# heart_rate_min             -0.062068  0.601761   6.111546
# heart_rate_max             -0.101996  0.574891   9.277717
# heart_rate_mean            -0.084843  0.650568   5.625750
# mbp_min                    -0.032199  0.567171   5.437052
# mbp_max                    -0.149254  0.407563   8.288667
# mbp_mean                   -0.119387  0.606076   6.146404
# sbp_min                    -0.086793  0.571684   5.360607
# sbp_max                    -0.074005  0.582296   8.939203
# sbp_mean                   -0.120740  0.632475   5.030577
# dbp_min                    -0.032045  0.558481   5.535772
# dbp_max                    -0.118286  0.525796   9.047490
# dbp_mean                   -0.105966  0.603318   5.646617
# temperature_min             0.167578  0.586933   4.032935
# temperature_max            -0.202594  0.424346   7.561815
# temperature_mean           -0.049750  0.471161   6.486938
# lactate_min                -0.233260  0.251692  14.703267
# lactate_max                -0.270025  0.257890  15.626088
# ph_min                      0.045751  0.716464   3.175745
# ph_max                      0.048197  0.617649   6.027448
# chloride_min                0.125831  0.458353   5.944968
# chloride_max                0.101378  0.583716   5.728656
# calcium_min                 0.042746  0.555751  10.302857
# calcium_max                -0.076891  0.474282  13.387490
# sodium_min                  0.033780  0.371136   8.636354
# sodium_max                  0.064259  0.410476   8.546569
# glucose_min                -0.217006  0.359091  11.455219
# glucose_max                -0.267910  0.094336  20.079675
# wbc_min                    -0.151570  0.259099  37.244937
# wbc_max                    -0.157519  0.230473  35.555752
# creatinine_min             -0.293416 -0.020694  20.774383
# creatinine_max             -0.320273  0.004504  22.414131
# hemoglobin_min              0.002947  0.704643   3.949986
# hemoglobin_max             -0.042827  0.693676   4.744444
# total_protein_max           0.054756  0.615168   9.675162
# total_protein_min          -0.016609  0.561140   9.997706
# pt_min                     -0.278205  0.023425  18.905484
# pt_max                     -0.281184 -0.023442  12.223743
# alt_max                    -0.123636 -0.092012  78.088057
# alt_min                    -0.153984 -0.098337  29.331296
# alp_max                    -0.271760  0.046938  23.964126
# alp_min                    -0.270427  0.056644  25.442349
# ast_min                    -0.152357 -0.089352  40.994146
# ast_max                    -0.141284 -0.103006  30.000452
# bilirubin_total_max        -0.269766 -0.099019  18.610018
# bilirubin_total_min        -0.241296 -0.106589  17.863338
# bilirubin_direct_max       -0.338363  0.076773  11.379790
# bilirubin_direct_min       -0.335371  0.075567  11.836221
# bilirubin_indirect_max     -0.373142  0.150019   8.433410
# bilirubin_indirect_min     -0.334393  0.116172   8.767026
# urineoutput                -0.195748  0.461768  22.970468
# sofa_respiration            0.469463  0.469463   0.469463
# sofa_coagulation           -0.583139  0.628932   4.265144
# sofa_liver                 -0.533429  0.504182   3.617015
# sofa_cardiovascular        -0.062088 -0.062088   3.022709
# sofa_cns                    0.080482  0.080482   2.935555
# sofa_renal                 -0.687885  0.144401   2.641259
# charlson_comorbidity_index  0.066969  0.730365   4.710744

# %%
#Dataset 5 was created to with sofa respiration as focus.
df5 = df_norm.dropna(subset=['sofa_respiration'])
df5 = df5.dropna(thresh=len(df5)*0.8, axis=1)
df5 = df5.dropna()
df5.describe().transpose()
# Out:
#                              count      mean       std        min       25%  \
# gender                      5847.0  0.183197  0.966227  -1.094033 -1.094033
# age                         5847.0  0.066630  0.873582  -2.844076 -0.454347
# heart_rate_min              5847.0  0.020232  0.927802  -4.111428 -0.659515
# heart_rate_max              5847.0  0.011956  0.900244  -2.132655 -0.633835
# heart_rate_mean             5847.0  0.076423  0.890584  -2.737331 -0.544949
# mbp_min                     5847.0 -0.149295  0.851840  -4.452553 -0.556648
# mbp_max                     5847.0 -0.045082  1.127298  -1.948202 -0.663239
# mbp_mean                    5847.0 -0.207398  0.767866  -2.852982 -0.712894
# sbp_min                     5847.0 -0.257588  0.842547  -5.115162 -0.745270
# sbp_max                     5847.0 -0.053992  0.914941  -2.874225 -0.686553
# sbp_mean                    5847.0 -0.192443  0.794136  -2.736295 -0.730081
# dbp_min                     5847.0 -0.162511  0.798742  -3.743924 -0.622571
# dbp_max                     5847.0 -0.298170  0.955297  -3.041425 -0.960546
# dbp_mean                    5847.0 -0.328604  0.819444  -3.047606 -0.874070
# temperature_min             5847.0 -0.276589  1.315451 -26.160605 -0.835226
# temperature_max             5847.0  0.141291  1.027284  -4.398268 -0.572327
# temperature_mean            5847.0  0.000224  1.076720  -5.969966 -0.596363
# lactate_min                 5847.0 -0.153334  0.786337  -1.397146 -0.621222
# lactate_max                 5847.0  0.035962  0.910960  -1.267199 -0.504654
# ph_min                      5847.0 -0.217184  0.886911  -7.108519 -0.624961
# ph_max                      5847.0  0.260901  0.907459  -6.073418 -0.236530
# glucose_min                 5847.0  0.058167  0.909678  -2.571490 -0.492531
# glucose_max                 5847.0 -0.061724  0.788107  -1.018906 -0.471120
# wbc_min                     5847.0  0.100528  0.954960  -1.293742 -0.369738
# wbc_max                     5847.0  0.224970  0.964438  -1.177125 -0.220680
# creatinine_min              5847.0 -0.136043  0.670321  -0.838861 -0.429778
# creatinine_max              5847.0 -0.130194  0.664058  -0.753309 -0.428532
# hemoglobin_min              5847.0 -0.230501  0.845908  -3.505531 -0.830316
# hemoglobin_max              5847.0 -0.020949  0.900747  -2.436462 -0.641236
# pt_min                      5847.0 -0.062192  0.859715  -0.926711 -0.429021
# pt_max                      5847.0 -0.012589  0.824351  -0.707791 -0.334510
# urineoutput                 5847.0  0.039201  0.913434  -1.511571 -0.564368
# sofa_respiration            5847.0  0.014329  0.975538  -2.929216  0.469463
# sofa_coagulation            5847.0  0.202935  0.999683  -0.583139 -0.583139
# sofa_cardiovascular         5847.0  0.199243  1.045736  -1.090354 -0.062088
# sofa_cns                    5847.0  0.254478  1.202256  -0.871209 -0.871209
# sofa_renal                  5847.0 -0.147120  0.846449  -0.687885 -0.687885
# charlson_comorbidity_index  5847.0 -0.047625  0.935272  -1.923221 -0.596428
#
#                                  50%       75%        max
# gender                      0.914024  0.914024   0.914024
# age                         0.134123  0.693970   1.912139
# heart_rate_min             -0.062068  0.601761   3.788143
# heart_rate_max             -0.101996  0.526542   5.796586
# heart_rate_mean            -0.046843  0.613975   4.594828
# mbp_min                    -0.107121  0.342407   3.339257
# mbp_max                    -0.277750  0.236235   8.245834
# mbp_mean                   -0.317822  0.189280   3.740576
# sbp_min                    -0.266378  0.212515   3.624622
# sbp_max                    -0.205265  0.407283   8.939203
# sbp_mean                   -0.310156  0.197948   4.389198
# dbp_min                    -0.200767  0.305398   3.258029
# dbp_max                    -0.489871  0.178983   8.452953
# dbp_mean                   -0.432193  0.099692   3.599830
# temperature_min             0.076414  0.386372   4.032935
# temperature_max            -0.122217  0.649402   6.661593
# temperature_mean           -0.080593  0.559121   6.334145
# lactate_min                -0.330251  0.057711  13.733363
# lactate_max                -0.152711  0.316547  15.626088
# ph_min                     -0.177820  0.269322   2.728603
# ph_max                      0.332923  0.902375   6.027448
# glucose_min                -0.091768  0.384138   7.748160
# glucose_max                -0.285580  0.067830  11.279764
# wbc_min                    -0.023236  0.374599  21.536864
# wbc_max                     0.104150  0.483118  27.588390
# creatinine_min             -0.293416 -0.088875   8.297337
# creatinine_max             -0.320273 -0.103755   9.801950
# hemoglobin_min             -0.260189  0.288011   3.949986
# hemoglobin_max             -0.088858  0.555582   4.007941
# pt_min                     -0.263124 -0.051983  10.761465
# pt_max                     -0.201195 -0.014554  11.814911
# urineoutput                -0.106553  0.442035   7.877578
# sofa_respiration            0.469463  0.469463   0.469463
# sofa_coagulation           -0.583139  0.628932   4.265144
# sofa_cardiovascular        -0.062088 -0.062088   3.022709
# sofa_cns                    0.080482  1.032173   2.935555
# sofa_renal                 -0.687885  0.144401   2.641259
# charlson_comorbidity_index -0.264730  0.398667   3.715649

# %%
df5['outcome'].value_counts()
# Out:
# False    5454
# True      393
# Name: outcome, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# %%
df_list = []
for xy in [df5]:
    X, y = xy.iloc[:, 0:-1], xy.iloc[:, -1]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=12, stratify=y, shuffle=True)
    
    smote_sampler = SMOTE(random_state=12,sampling_strategy='minority')
    X_s, y_s = smote_sampler.fit_resample(X_train, y_train)
    
    df_list.append([X_s, y_s, X_test, y_test])



print(f'For train data:')
print(y_s.value_counts())
print(y_s.value_counts(normalize=True))
print()
print(f'For test data:')
print(y_test.value_counts())
print(y_test.value_counts(normalize=True))

df_list[0][0]
# Out:
# For train data:
# False    3817
# True     3817
# Name: outcome, dtype: int64
# False    0.5
# True     0.5
# Name: outcome, dtype: float64
#
# For test data:
# False    1637
# True      118
# Name: outcome, dtype: int64
# False    0.932764
# True     0.067236
# Name: outcome, dtype: float64
#         gender       age  heart_rate_min  heart_rate_max  heart_rate_mean  \
# 0     0.914024 -0.468181        1.597506        1.348475         1.657195
# 1    -1.094033 -1.877306        1.066442        0.768287         0.895705
# 2     0.914024  0.133887        0.867293        0.284796         0.888119
# 3     0.914024  0.095333       -0.261217        0.091400         0.281162
# 4    -1.094033  0.217937       -0.062068       -0.343741        -0.291384
# ...        ...       ...             ...             ...              ...
# 7629 -0.622105  0.136742        1.452492        0.824874         1.466156
# 7630  0.914024 -0.965234       -0.442773        0.313328        -0.539588
# 7631  0.914024  0.019271       -0.718825       -0.624587        -0.411337
# 7632  0.914024  0.941932        2.045419        1.372399         1.951436
# 7633 -1.094033 -0.199884       -0.480230       -0.143400        -0.501713
#
#        mbp_min   mbp_max  mbp_mean   sbp_min   sbp_max  ...  hemoglobin_max  \
# 0    -0.256963  0.022074 -0.307403 -0.685409  0.801064  ...       -1.423770
# 1     0.642092 -0.106422 -0.074337 -0.026932 -0.380279  ...       -0.779330
# 2     0.791934  0.107738  0.555842 -0.146655 -0.292772  ...        0.325425
# 3     1.166541  0.321899  0.783235  0.571684  0.451036  ...        0.555582
# 4    -3.178892  0.064906 -0.783592 -3.738347 -0.205265  ...        0.141299
# ...        ...       ...       ...       ...       ...  ...             ...
# 7629  0.038584 -0.640540 -0.392720 -0.847337 -1.250309  ...        1.108176
# 7630  0.182636  2.449708  0.504588 -1.012849  1.338037  ...       -0.538464
# 7631 -0.449797  4.926596 -0.236985 -0.554812 -0.080998  ...       -0.562882
# 7632  1.635768  0.354355  1.518317  0.681327  0.233628  ...        2.883808
# 7633  0.582659  0.764807  1.183638  0.682808  1.677941  ...        0.309296
#
#         pt_min    pt_max  urineoutput  sofa_respiration  sofa_coagulation  \
# 0     0.053588 -0.058992    -0.873788          0.469463          1.841003
# 1    -0.398858 -0.414498    -0.181540          0.469463          0.628932
# 2    -0.142472 -0.067880    -0.674875         -1.229876          1.841003
# 3    -0.112309 -0.094543     0.667785          0.469463          0.628932
# 4     0.053588  6.793387    -1.393171         -1.229876         -0.583139
# ...        ...       ...          ...               ...               ...
# 7629 -0.246926 -0.313455    -0.572192          0.469463         -0.583139
# 7630  0.021124 -0.130450    -1.385232          0.469463         -0.583139
# 7631 -0.553032 -0.271543    -1.174441          0.469463         -0.583139
# 7632 -0.328685 -0.279503    -0.125121          0.469463          0.526881
# 7633 -0.259087 -0.297769    -0.430010         -0.564193         -0.583139
#
#       sofa_cardiovascular  sofa_cns  sofa_renal  charlson_comorbidity_index
# 0               -0.062088 -0.871209   -0.687885                    0.066969
# 1               -0.062088  1.983864   -0.687885                   -1.923221
# 2                1.994443  0.080482    0.144401                   -0.264730
# 3               -1.090354  2.935555   -0.687885                   -0.596428
# 4               -0.062088  1.983864    2.641259                    1.062063
# ...                   ...       ...         ...                         ...
# 7629             3.022709  2.935555   -0.687885                    1.335686
# 7630             3.022709  1.032173    2.641259                    0.723722
# 7631            -0.423103  2.601424    2.349051                    1.044393
# 7632            -1.090354  1.823607   -0.617810                    0.259029
# 7633            -0.687550  2.189942    0.324623                    0.802191
#
# [7634 rows x 38 columns]

# %%
#feature selection packages
from sklearn.feature_selection import SequentialFeatureSelector as SFS

#models packages

from sklearn.tree import DecisionTreeClassifier as DTC
from sklearn.linear_model import LogisticRegression as LR
from xgboost import XGBClassifier as XGBC
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier as ABC
from sklearn.ensemble import RandomForestClassifier as RFC

#others
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.metrics import f1_score, roc_auc_score, roc_curve, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ## Model Training

# %%
#Running through all models to get a rough idea of the datasets
allrec = []
allXy = []

for i, dataset in enumerate(df_list):
    print(f'For dataset {i+5}:')
    models = {
        'SVM_linear':SVC(kernel='linear',probability=True),
        'AdaBoost':ABC(),
        'SVM_rbf':SVC(kernel='rbf', probability=True)
    }
    
    rec = {}
    Xy_test = pd.concat([dataset[2], dataset[3]],axis=1)
    
    for model in models:
        st = time.time()
        fitted = models[model].fit(dataset[0], dataset[1])
        Xy_test[model] = fitted.predict(dataset[2])
        Xy_test[model+'_ProbTrue'] = fitted.predict_proba(dataset[2])[:,1]
        rec[model] = fitted
        et = time.time()
        print('For {}, F1 score is {:.4f}.'.format(
            model,f1_score(Xy_test['outcome'],Xy_test[model])))
        print(f'Runtime = {et-st}')
    
    allrec.append(rec)
    allXy.append(Xy_test)
# Out:
# For dataset 5:
# For SVM_linear, F1 score is 0.2194.
# Runtime = 21.136067628860474
# For AdaBoost, F1 score is 0.1966.
# Runtime = 1.4944183826446533
# For SVM_rbf, F1 score is 0.1917.
# Runtime = 10.938256978988647

# %%
#Creating a function to view contingency table

def ViewResult(result, models):
    for model in models:
        data_crosstab = pd.crosstab(
            index=result['outcome'],
            columns=result[model],
            rownames=['Label'],
            colnames=['Pred']
        )
        print(f' Contingency Table for {model}:')
        print(data_crosstab)
        print('F1 Score:', f1_score(result['outcome'], result[model]))
        print()
        
    plt.figure(0).clear()
    
    for model in models:
        pred = result[model]
        pred_prob = result[model+'_ProbTrue']
        label = result['outcome']
        fpr, tpr, thresh = roc_curve(label, pred_prob)
        auc = roc_auc_score(label, pred_prob)
        plt.plot(fpr,tpr,label=f"{model}, auc="+str(auc))
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
    plt.legend(loc=0)
    
    plt.figure(1).clear()
    for model in models:
        pred = result[model]
        pred_prob = result[model+'_ProbTrue']
        label = result['outcome']
        pre, rec, thresh = precision_recall_curve(label, pred_prob)
        avgprecision = average_precision_score(label, pred_prob)
        plt.plot(rec,pre,label=f"{model}, avgprec="+str(avgprecision))
        plt.xlabel('Recall')
        plt.ylabel('Precision')

    plt.legend(loc=0)

# %%
ViewResult(allXy[0], models)
# Out:
#  Contingency Table for SVM_linear:
# Pred   False  True
# Label
# False   1130    507
# True      41     77
# F1 Score: 0.21937321937321938
#
#  Contingency Table for AdaBoost:
# Pred   False  True
# Label
# False   1434    203
# True      83     35
# F1 Score: 0.19662921348314605
#
#  Contingency Table for SVM_rbf:
# Pred   False  True
# Label
# False   1472    165
# True      88     30
# F1 Score: 0.1916932907348243

# %%
#Function for GridSearchCV for Best Parameters

def GridSearchBP(mod, par, dat):
    rec = {}
    Xy_test = pd.concat([dat[2], dat[3]],axis=1)

    stratifiedCV = StratifiedKFold(n_splits=5)

    for model in mod:
        st = time.time()
        BestParams = GridSearchCV(
            mod[model],
            param_grid = par[model],
            scoring='f1',
            cv=stratifiedCV,
            n_jobs=-1
        )
        BestParams.fit(dat[0], dat[1])
        Xy_test[model] = BestParams.predict(dat[2])
        Xy_test[model+'_ProbTrue'] = BestParams.predict_proba(dat[2])[:,1]
        rec[model] = BestParams
        et = time.time()
        print('For {} cross validation F1 score is {:.4f}'.format(model,BestParams.best_score_))
        print(f'Parameters are {BestParams.best_params_}.')
        print(f'Runtime = {et-st}')
    return (rec, Xy_test)

# %%
models = {
    'SVM_linear':SVC(kernel='linear', probability=True),
    'AdaBoost':ABC(),
    'SVM_rbf':SVC(kernel='rbf', probability=True)
}
params = {
    'SVM_linear':{
        'C':[0.1,1,10,20]
    },
    'AdaBoost':{
        'n_estimators':[1,10,100,150],
        'learning_rate':[0.1,1,10]
    },
    'SVM_rbf':{
        'C':[0.1,1,10,20]
    }
}

# %%
data = df_list[0]
rec5, dfresult5 = GridSearchBP(models, params, data)
# Out:
# For SVM_linear cross validation F1 score is 0.7471
# Parameters are {'C': 20}.
# Runtime = 309.9579918384552
# For AdaBoost cross validation F1 score is 0.9178
# Parameters are {'learning_rate': 1, 'n_estimators': 150}.
# Runtime = 16.39539098739624
# For SVM_rbf cross validation F1 score is 0.9780
# Parameters are {'C': 20}.
# Runtime = 33.81716322898865

# %%
#setting parameters based on an initial GridSearch ran
models_2 = {
    'SVM_linear':SVC(kernel='linear', probability=True, C=20),
    'AdaBoost':ABC(learning_rate=1, n_estimators=150),
    'SVM_rbf':SVC(kernel='rbf', probability=True, C=20)
}

# %%
#Testing of feature selection with auto setting and best parameters from above.

fsrec5={}

for model in models_2:
    feature_selection = SFS(
        models_2[model], n_features_to_select='auto', direction="forward", n_jobs=-1
    ).fit(data[0], data[1])
    
    fsrec5[model] = feature_selection
    print(model, feature_selection.n_features_to_select_, data[0].columns[feature_selection.support_])
# Out:
# SVM_linear 19 Index(['gender', 'heart_rate_max', 'heart_rate_mean', 'mbp_max', 'mbp_mean',
#        'sbp_mean', 'dbp_max', 'dbp_mean', 'temperature_max',
#        'temperature_mean', 'lactate_min', 'lactate_max', 'ph_min', 'ph_max',
#        'glucose_min', 'wbc_max', 'urineoutput', 'sofa_respiration',
#        'sofa_cns'],
#       dtype='object')
# AdaBoost 19 Index(['gender', 'age', 'heart_rate_max', 'dbp_min', 'lactate_min', 'ph_min',
#        'glucose_min', 'wbc_min', 'wbc_max', 'creatinine_min', 'hemoglobin_min',
#        'hemoglobin_max', 'pt_max', 'sofa_respiration', 'sofa_coagulation',
#        'sofa_cardiovascular', 'sofa_cns', 'sofa_renal',
#        'charlson_comorbidity_index'],
#       dtype='object')

# %%
#Creating a function for feature selection and fitting of best hyperparameters

def FeatureSelect_BestParams(models, models2, params, data, n_features):
    fsrec = {}
    bprec = {}
    dfresult = pd.concat([data[2],data[3]],axis=1)
    stratifiedCV = StratifiedKFold(n_splits=5)
    
    for model in models2:
        st = time.time()
        feature_selection = SFS(
            models2[model], n_features_to_select=n_features, direction="forward", n_jobs=-1
        ).fit(data[0], data[1])

        fsrec[model] = feature_selection
        print(model, feature_selection.n_features_to_select_, data[0].columns[feature_selection.support_])

        X = data[0].loc[:,list(data[0].columns[feature_selection.support_])]
        X_test = data[2].loc[:,list(data[0].columns[feature_selection.support_])]

        BestParams = GridSearchCV(
            models[model],
            param_grid = params[model],
            scoring='f1',
            n_jobs=-1
        )
        BestParams.fit(X,data[1])
        dfresult[model] = BestParams.predict(X_test)
        dfresult[model+'_ProbTrue'] = BestParams.predict_proba(X_test)[:,1]
        bprec[model] = BestParams
        et = time.time()
        print('For {} cross validation F1 score is {:.4f}'.format(model,BestParams.best_score_))
        print(f'Best parameters are {BestParams.best_params_}.')
        print(f'Runtime = {et-st}')
    return (fsrec, bprec, dfresult)

# %%
#Training and evaluating models with 10 features
data=df_list[0]

fs_rec5_10, bp_rec5_10, dfresult5_10 = FeatureSelect_BestParams(models, models_2, params, data, 10)

# %%
ViewResult(dfresult5_10, models)

# %%
#Cross-validation f1 score of models is significantly higher than f1 score on test data. 
#There could be possible overfitting.
#Training and testing for 5 features instead to try reduce overfitting.

data=df_list[0]

fs_rec5_5, bp_rec5_5, dfresult5_5 = FeatureSelect_BestParams(models, models_2, params, data, 5)

# %%
ViewResult(dfresult5_5, models)

# %%
data=df_list[0]

fs_rec5_15, bp_rec5_15, dfresult5_15 = FeatureSelect_BestParams(models, models_2, params, data, 15)

# %%
ViewResult(dfresult4_15, models)

# %%
data=df_list[0]

fs_rec5_8, bp_rec5_8, dfresult5_8 = FeatureSelect_BestParams(models, models_2, params, data, 8)

# %%
ViewResult(dfresult5_8, models)
