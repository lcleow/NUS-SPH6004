# %% [markdown]
# ## Data Processing

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'Assignment_1_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36489 entries, 0 to 36488
# Data columns (total 60 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   gender                      36489 non-null  object
#  1   age                         36489 non-null  float64
#  2   heart_rate_min              36417 non-null  float64
#  3   heart_rate_max              36417 non-null  float64
#  4   heart_rate_mean             36417 non-null  float64
#  5   mbp_min                     36401 non-null  float64
#  6   mbp_max                     36401 non-null  float64
#  7   mbp_mean                    36401 non-null  float64
#  8   sbp_min                     36343 non-null  float64
#  9   sbp_max                     36343 non-null  float64
#  10  sbp_mean                    36343 non-null  float64
#  11  dbp_min                     36341 non-null  float64
#  12  dbp_max                     36341 non-null  float64
#  13  dbp_mean                    36341 non-null  float64
#  14  temperature_min             36126 non-null  float64
#  15  temperature_max             36126 non-null  float64
#  16  temperature_mean            36126 non-null  float64
#  17  lactate_min                 15930 non-null  float64
#  18  lactate_max                 15930 non-null  float64
#  19  ph_min                      18860 non-null  float64
#  20  ph_max                      18860 non-null  float64
#  21  chloride_min                6129 non-null   float64
#  22  chloride_max                6129 non-null   float64
#  23  calcium_min                 9289 non-null   float64
#  24  calcium_max                 9289 non-null   float64
#  25  sodium_min                  6554 non-null   float64
#  26  sodium_max                  6554 non-null   float64
#  27  glucose_min                 36191 non-null  float64
#  28  glucose_max                 36191 non-null  float64
#  29  wbc_min                     36235 non-null  float64
#  30  wbc_max                     36235 non-null  float64
#  31  creatinine_min              36291 non-null  float64
#  32  creatinine_max              36291 non-null  float64
#  33  hemoglobin_min              36232 non-null  float64
#  34  hemoglobin_max              36232 non-null  float64
#  35  total_protein_max           974 non-null    float64
#  36  total_protein_min           974 non-null    float64
#  37  pt_min                      32345 non-null  float64
#  38  pt_max                      32345 non-null  float64
#  39  alt_max                     18663 non-null  float64
#  40  alt_min                     18663 non-null  float64
#  41  alp_max                     18580 non-null  float64
#  42  alp_min                     18580 non-null  float64
#  43  ast_min                     18776 non-null  float64
#  44  ast_max                     18776 non-null  float64
#  45  bilirubin_total_max         18590 non-null  float64
#  46  bilirubin_total_min         18590 non-null  float64
#  47  bilirubin_direct_max        1605 non-null   float64
#  48  bilirubin_direct_min        1605 non-null   float64
#  49  bilirubin_indirect_max      1544 non-null   float64
#  50  bilirubin_indirect_min      1544 non-null   float64
#  51  urineoutput                 35073 non-null  float64
#  52  sofa_respiration            7587 non-null   float64
#  53  sofa_coagulation            36235 non-null  float64
#  54  sofa_liver                  18590 non-null  float64
#  55  sofa_cardiovascular         36402 non-null  float64
#  56  sofa_cns                    36468 non-null  float64
#  57  sofa_renal                  36467 non-null  float64
#  58  charlson_comorbidity_index  36489 non-null  int64
#  59  outcome                     36489 non-null  bool
# dtypes: bool(1), float64(57), int64(1), object(1)
# memory usage: 16.5+ MB

# %%
df.head(10)
# Out:
#   gender        age  heart_rate_min  heart_rate_max  heart_rate_mean  mbp_min  \
# 0      M  54.550390            93.0           115.0       103.500000     57.0
# 1      M  86.324653            50.0            61.0        54.333333     61.0
# 2      M  40.270146            70.0           105.0        83.434783     66.0
# 3      M  73.383547            68.0            98.0        83.880000     74.0
# 4      M  70.724748            77.0            95.0        85.771429     30.0
# 5      F  24.131524            82.0           111.0        95.640000     53.0
# 6      M  68.308897            60.0            80.0        71.083333     63.0
# 7      F  57.433933            62.0            92.0        75.240000     65.0
# 8      M  62.564975            48.0            87.0        59.000000     56.0
# 9      M  66.238225            61.0            80.0        69.750000     61.0
#
#    mbp_max   mbp_mean  sbp_min  sbp_max  ...  bilirubin_indirect_min  \
# 0    100.0  82.733333     87.0    163.0  ...                     NaN
# 1     93.0  71.695652     95.0    141.0  ...                     NaN
# 2     92.0  76.695652     94.0    129.0  ...                     NaN
# 3    101.0  84.694444     83.0    148.0  ...                     NaN
# 4     90.0  62.657143     52.0    129.0  ...                     NaN
# 5    113.0  77.520000     86.0    136.0  ...                     NaN
# 6    112.0  75.720000     87.0    153.0  ...                     NaN
# 7     97.0  78.160000     88.0    125.0  ...                     NaN
# 8     86.0  71.954545    104.0    140.0  ...                     NaN
# 9     92.0  74.958333     93.0    127.0  ...                     NaN
#
#    urineoutput  sofa_respiration  sofa_coagulation  sofa_liver  \
# 0       3459.0               2.0               0.0         NaN
# 1       2020.0               NaN               1.0         NaN
# 2       3050.0               NaN               1.0         0.0
# 3       1592.0               NaN               0.0         NaN
# 4        339.0               2.0               0.0         0.0
# 5       6000.0               NaN               0.0         NaN
# 6       2560.0               1.0               1.0         NaN
# 7       2200.0               NaN               2.0         0.0
# 8        800.0               NaN               1.0         NaN
# 9       1925.0               NaN               0.0         NaN
#
#    sofa_cardiovascular  sofa_cns  sofa_renal  charlson_comorbidity_index  \
# 0                  1.0       0.0         1.0                           3
# 1                  1.0       1.0         1.0                           8
# 2                  1.0       1.0         0.0                           4
# 3                  0.0       0.0         1.0                           6
# 4                  4.0       1.0         3.0                          10
# 5                  1.0       0.0         0.0                           1
# 6                  1.0       1.0         0.0                           3
# 7                  3.0       0.0         0.0                           4
# 8                  1.0       0.0         0.0                           4
# 9                  1.0       0.0         2.0                           7
#
#    outcome
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
#
# [10 rows x 60 columns]

# %%
df['gender'].replace({'M':1, 'F':0}, inplace=True)

# %%
df_norm = df.copy()
for col in df_norm:
    if df_norm[col].dtype == 'float64' or df_norm[col].dtype == 'int64':
        df_norm[col] = (df_norm[col] - df_norm[col].mean())/df_norm[col].std()

# %%
df_norm.describe().transpose()
# Out:
#                               count          mean  std        min       25%  \
# gender                      36489.0  7.465443e-16  1.0  -1.094033 -1.094033
# age                         36489.0 -3.137110e-14  1.0  -2.851891 -0.616634
# heart_rate_min              36417.0 -2.963399e-16  1.0  -4.111428 -0.725898
# heart_rate_max              36417.0  2.501035e-17  1.0  -3.244683 -0.730533
# heart_rate_mean             36417.0  1.051775e-14  1.0  -3.527194 -0.721902
# mbp_min                     36401.0 -4.249658e-16  1.0  -4.465290 -0.556648
# mbp_max                     36401.0 -8.566172e-17  1.0  -2.333690 -0.620407
# mbp_mean                    36401.0 -6.561921e-15  1.0  -3.124648 -0.710890
# sbp_min                     36343.0  3.985590e-16  1.0  -5.534193 -0.655478
# sbp_max                     36343.0 -4.348758e-16  1.0  -4.318088 -0.686553
# sbp_mean                    36343.0  4.231022e-14  1.0  -4.631456 -0.735232
# dbp_min                     36341.0  6.560217e-16  1.0  -3.912645 -0.622571
# dbp_max                     36341.0 -4.145564e-16  1.0  -3.041425 -0.712823
# dbp_mean                    36341.0 -1.090939e-14  1.0  -3.047606 -0.702753
# temperature_min             36126.0 -3.401823e-14  1.0 -26.160605 -0.324708
# temperature_max             36126.0  5.444893e-13  1.0  -6.263012 -0.572327
# temperature_mean            36126.0 -4.543138e-13  1.0  -8.689622 -0.508974
# lactate_min                 15930.0  1.304600e-15  1.0  -1.591127 -0.621222
# lactate_max                 15930.0 -5.177418e-15  1.0  -1.267199 -0.621969
# ph_min                      18860.0  1.952616e-13  1.0  -7.220305 -0.513176
# ph_max                      18860.0  3.321816e-13  1.0  -8.493592 -0.663619
# chloride_min                 6129.0 -1.542103e-15  1.0 -16.600030 -0.372952
# chloride_max                 6129.0  2.136758e-16  1.0 -16.394583 -0.380960
# calcium_min                  9289.0 -8.043957e-14  1.0  -7.036731 -0.470260
# calcium_max                  9289.0  3.411752e-14  1.0  -4.407540 -0.628065
# sodium_min                   6554.0  9.840567e-16  1.0 -22.508336 -0.303575
# sodium_max                   6554.0 -1.471715e-16  1.0 -22.768733 -0.281957
# glucose_min                 36191.0 -5.687473e-18  1.0  -2.771871 -0.617769
# glucose_max                 36191.0 -9.129407e-17  1.0  -1.416492 -0.479956
# wbc_min                     36235.0 -5.480397e-15  1.0  -1.293742 -0.459571
# wbc_max                     36235.0 -4.993215e-15  1.0  -1.177125 -0.437234
# creatinine_min              36291.0  2.006612e-14  1.0  -0.838861 -0.429778
# creatinine_max              36291.0  9.506918e-15  1.0  -0.807439 -0.428532
# hemoglobin_min              36232.0  9.630198e-15  1.0  -3.549387 -0.742604
# hemoglobin_max              36232.0 -3.367256e-16  1.0  -3.541217 -0.733299
# total_protein_max             974.0 -3.375409e-15  1.0  -3.774726 -0.599058
# total_protein_min             974.0 -1.250283e-15  1.0  -3.868268 -0.594358
# pt_min                      32345.0 -1.366040e-15  1.0  -1.047363 -0.459184
# pt_max                      32345.0  6.666300e-15  1.0  -0.805555 -0.423386
# alt_max                     18663.0 -1.436187e-16  1.0  -0.153995 -0.136285
# alt_min                     18663.0 -1.557200e-16  1.0  -0.209631 -0.174219
# alp_max                     18580.0  2.802148e-17  1.0  -0.872099 -0.442227
# alp_min                     18580.0 -2.213873e-18  1.0  -0.907795 -0.446541
# ast_min                     18776.0 -1.190226e-16  1.0  -0.215362 -0.176256
# ast_max                     18776.0  4.757148e-17  1.0  -0.176130 -0.155011
# bilirubin_total_max         18590.0 -3.610220e-15  1.0  -0.391728 -0.318551
# bilirubin_total_min         18590.0 -4.732883e-15  1.0  -0.376003 -0.295179
# bilirubin_direct_max         1605.0  8.093215e-18  1.0  -0.621411 -0.527061
# bilirubin_direct_min         1605.0 -7.899531e-17  1.0  -0.609329 -0.531056
# bilirubin_indirect_max       1544.0 -1.898596e-15  1.0  -0.765513 -0.591126
# bilirubin_indirect_min       1544.0 -2.979051e-15  1.0  -0.739902 -0.559676
# urineoutput                 35073.0  9.451510e-17  1.0 -13.233208 -0.682769
# sofa_respiration             7587.0  1.322259e-16  1.0  -2.929216  0.469463
# sofa_coagulation            36235.0  2.894326e-15  1.0  -0.583139 -0.583139
# sofa_liver                  18590.0  6.634583e-16  1.0  -0.533429 -0.533429
# sofa_cardiovascular         36402.0  1.594485e-17  1.0  -1.090354 -0.062088
# sofa_cns                    36468.0  6.844792e-16  1.0  -0.871209 -0.871209
# sofa_renal                  36467.0 -5.947412e-16  1.0  -0.687885 -0.687885
# charlson_comorbidity_index  36489.0  5.748429e-17  1.0  -1.923221 -0.596428
#
#                                  50%       75%        max
# gender                      0.914024  0.914024   0.914024
# age                         0.091196  0.763350   2.200235
# heart_rate_min             -0.062068  0.601761   6.111546
# heart_rate_max             -0.101996  0.574891   9.277717
# heart_rate_mean            -0.084843  0.650568   5.625750
# mbp_min                    -0.032199  0.567171   5.437052
# mbp_max                    -0.149254  0.407563   8.288667
# mbp_mean                   -0.119387  0.606076   6.146404
# sbp_min                    -0.086793  0.571684   5.360607
# sbp_max                    -0.074005  0.582296   8.939203
# sbp_mean                   -0.120740  0.632475   5.030577
# dbp_min                    -0.032045  0.558481   5.535772
# dbp_max                    -0.118286  0.525796   9.047490
# dbp_mean                   -0.105966  0.603318   5.646617
# temperature_min             0.167578  0.586933   4.032935
# temperature_max            -0.202594  0.424346   7.561815
# temperature_mean           -0.049750  0.471161   6.486938
# lactate_min                -0.233260  0.251692  14.703267
# lactate_max                -0.270025  0.257890  15.626088
# ph_min                      0.045751  0.716464   3.175745
# ph_max                      0.048197  0.617649   6.027448
# chloride_min                0.125831  0.458353   5.944968
# chloride_max                0.101378  0.583716   5.728656
# calcium_min                 0.042746  0.555751  10.302857
# calcium_max                -0.076891  0.474282  13.387490
# sodium_min                  0.033780  0.371136   8.636354
# sodium_max                  0.064259  0.410476   8.546569
# glucose_min                -0.217006  0.359091  11.455219
# glucose_max                -0.267910  0.094336  20.079675
# wbc_min                    -0.151570  0.259099  37.244937
# wbc_max                    -0.157519  0.230473  35.555752
# creatinine_min             -0.293416 -0.020694  20.774383
# creatinine_max             -0.320273  0.004504  22.414131
# hemoglobin_min              0.002947  0.704643   3.949986
# hemoglobin_max             -0.042827  0.693676   4.744444
# total_protein_max           0.054756  0.615168   9.675162
# total_protein_min          -0.016609  0.561140   9.997706
# pt_min                     -0.278205  0.023425  18.905484
# pt_max                     -0.281184 -0.023442  12.223743
# alt_max                    -0.123636 -0.092012  78.088057
# alt_min                    -0.153984 -0.098337  29.331296
# alp_max                    -0.271760  0.046938  23.964126
# alp_min                    -0.270427  0.056644  25.442349
# ast_min                    -0.152357 -0.089352  40.994146
# ast_max                    -0.141284 -0.103006  30.000452
# bilirubin_total_max        -0.269766 -0.099019  18.610018
# bilirubin_total_min        -0.241296 -0.106589  17.863338
# bilirubin_direct_max       -0.338363  0.076773  11.379790
# bilirubin_direct_min       -0.335371  0.075567  11.836221
# bilirubin_indirect_max     -0.373142  0.150019   8.433410
# bilirubin_indirect_min     -0.334393  0.116172   8.767026
# urineoutput                -0.195748  0.461768  22.970468
# sofa_respiration            0.469463  0.469463   0.469463
# sofa_coagulation           -0.583139  0.628932   4.265144
# sofa_liver                 -0.533429  0.504182   3.617015
# sofa_cardiovascular        -0.062088 -0.062088   3.022709
# sofa_cns                    0.080482  0.080482   2.935555
# sofa_renal                 -0.687885  0.144401   2.641259
# charlson_comorbidity_index  0.066969  0.730365   4.710744

# %%
data4 = df_norm.loc[:, ['age', 'sofa_respiration', 'sofa_cardiovascular', 'sofa_cns', 
                        'charlson_comorbidity_index', 'lactate_min', 'lactate_max','ph_min','ph_max', 'outcome']]
data4 = data4.dropna()
data4['outcome'].value_counts()
# Out:
# False    6330
# True      432
# Name: outcome, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# %%
d4 = []
X, y = data4.iloc[:, 0:-1], data4.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=12, stratify=y, shuffle=True)
    
smote_sampler = SMOTE(random_state=12,sampling_strategy='minority')
X_s, y_s = smote_sampler.fit_resample(X_train, y_train)
    
d4.extend([X_s, y_s, X_test, y_test])

d4[3].value_counts()
# Out:
# False    1899
# True      130
# Name: outcome, dtype: int64

# %%
#feature selection packages
from sklearn.feature_selection import SequentialFeatureSelector as SFS

#models packages

from sklearn.tree import DecisionTreeClassifier as DTC
from sklearn.linear_model import LogisticRegression as LR
from xgboost import XGBClassifier as XGBC
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier as ABC
from sklearn.ensemble import RandomForestClassifier as RFC

#others
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.metrics import f1_score, roc_auc_score, roc_curve, precision_recall_curve
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ## Model Training

# %%
#Running through all models to get a rough idea of the datasets
allrec = []
allXy = []
d4_list = [d4]

for i, dataset in enumerate(d4_list):
    print(f'For dataset {i+1}:')
    models = {
        'LR':LR(),
        'SVM_linear':SVC(kernel='linear'),
        'DecisionTree':DTC(criterion='entropy'),
        'RandomForest':RFC(criterion='entropy'),
        'AdaBoost':ABC(),
        'XGBoost':XGBC(tree_method='gpu_hist'),
        'SVM_rbf':SVC(kernel='rbf')
    }
    
    rec = {}
    Xy_test = pd.concat([dataset[2], dataset[3]],axis=1)
    
    for model in models:
        st = time.time()
        fitted = models[model].fit(dataset[0], dataset[1])
        Xy_test[model] = fitted.predict(dataset[2])
        rec[model] = fitted
        et = time.time()
        print('For {}, F1 score is {:.4f}. AUC of ROC is {:.4f}'.format(
            model,f1_score(Xy_test['outcome'],Xy_test[model]),roc_auc_score(Xy_test['outcome'],Xy_test[model])))
        print(f'Runtime = {et-st}')
    
    allrec.append(rec)
    allXy.append(Xy_test)
# Out:
# For dataset 1:
# For LR, F1 score is 0.2237. AUC of ROC is 0.6817
# Runtime = 0.07471108436584473
# For SVM_linear, F1 score is 0.2339. AUC of ROC is 0.6959
# Runtime = 6.502708673477173
# For DecisionTree, F1 score is 0.1404. AUC of ROC is 0.5428
# Runtime = 0.12712645530700684
# For RandomForest, F1 score is 0.1244. AUC of ROC is 0.5327
# Runtime = 4.1041178703308105
# For AdaBoost, F1 score is 0.2584. AUC of ROC is 0.6689
# Runtime = 0.8087952136993408
# For XGBoost, F1 score is 0.0375. AUC of ROC is 0.5044
# Runtime = 0.7732956409454346
# For SVM_rbf, F1 score is 0.2051. AUC of ROC is 0.6329
# Runtime = 6.479395627975464

# %%
#Creating a function to view contingency table, ROC, and precision-recall curve

def ViewResult(result, models):
    for model in models:
        data_crosstab = pd.crosstab(
            index=result['outcome'],
            columns=result[model],
            rownames=['Label'],
            colnames=['Pred']
        )
        print(f' Contingency Table for {model}:')
        print(data_crosstab)
        print('F1 Score:', f1_score(result['outcome'], result[model]))
        print()

    plt.figure(0).clear()

    for model in models:
        pred = result[model]
        label = result['outcome']
        fpr, tpr, thresh = roc_curve(label, pred)
        auc = roc_auc_score(label, pred)
        plt.plot(fpr,tpr,label=f"{model}, auc="+str(auc))

    plt.legend(loc=0)
    
    plt.figure(1).clear()

    for model in models:
        pred = result[model]
        label = result['outcome']
        fpr, tpr, thresh = precision_recall_curve(label, pred)
        f1score = f1_score(label, pred)
        plt.plot(fpr,tpr,label=f"{model}, f1score="+str(f1score))

    plt.legend(loc=0)

# %%
for dataset in allXy:
    ViewResult(dataset, models)
# Out:
#  Contingency Table for LR:
# Pred   False  True
# Label
# False   1362   537
# True      46    84
# F1 Score: 0.22370173102529956
#
#  Contingency Table for SVM_linear:
# Pred   False  True
# Label
# False   1372   527
# True      43    87
# F1 Score: 0.2338709677419355
#
#  Contingency Table for DecisionTree:
# Pred   False  True
# Label
# False   1711   188
# True     106    24
# F1 Score: 0.14035087719298248
#
#  Contingency Table for RandomForest:
# Pred   False  True
# Label
# False   1848    51
# True     118    12
# F1 Score: 0.12435233160621761
#
#  Contingency Table for AdaBoost:
# Pred   False  True
# Label
# False   1591   308
# True      65    65
# F1 Score: 0.2584493041749503
#
#  Contingency Table for XGBoost:
# Pred      0   1
# Label
# False  1872  27
# True    127   3
# F1 Score: 0.0375
#
#  Contingency Table for SVM_rbf:
# Pred   False  True
# Label
# False   1469   430
# True      66    64
# F1 Score: 0.20512820512820512

# %%
#Function for GridSearchCV for Best Parameters

def GridSearchBP(mod, par, dat):
    rec = {}
    Xy_test = pd.concat([dat[2], dat[3]],axis=1)

    stratifiedCV = StratifiedKFold(n_splits=5)

    for model in mod:
        st = time.time()
        BestParams = GridSearchCV(
            mod[model],
            param_grid = par[model],
            scoring='f1',
            cv=stratifiedCV,
            n_jobs=-1
        )
        BestParams.fit(dat[0], dat[1])
        Xy_test[model] = BestParams.predict(dat[2])
        rec[model] = BestParams
        et = time.time()
        print('For {} cross validation F1 score is {:.4f}'.format(model,BestParams.best_score_))
        print(f'Parameters are {BestParams.best_params_}.')
        print(f'Runtime = {et-st}')
    return (rec, Xy_test)

# %%
#Getting initial hyperparameters using all features of dataset 1.
#Dataset 1 is chosen due to the smaller sample size, and limited available time and processing power.

dat = d4

#Different start/stop/step were set to figure out where the "best" parameters are encompassed.
#The below start/stop/step were decided after a few rounds of testing.
models = {
    'LR':LR(),
    'SVM_linear':SVC(kernel='linear'),
    'DecisionTree':DTC(criterion='entropy'),
    'RandomForest':RFC(criterion='entropy'),
    'AdaBoost':ABC(),
    'XGBoost':XGBC(tree_method='gpu_hist'),
    'SVM_rbf':SVC(kernel='rbf')
}
params = {
    'LR':{
        'C':np.arange(0.1,1,0.1)
    },
    'SVM_linear':{
        'C':np.arange(2,40)
    },
    'DecisionTree':{
        'max_depth':np.arange(1,20)
    },
    'RandomForest':{
        'n_estimators':np.arange(50,100),
        'max_depth':np.arange(1,20)
    },
    'AdaBoost':{
        'n_estimators':np.arange(100,200),
        'learning_rate':np.arange(0.1,1,0.1)
    },
    'XGBoost':{
        'n_estimators':np.arange(2,40),
        'max_depth':np.arange(2,10),
        'learning_rate':np.arange(0.1,1,0.1)
    },
    'SVM_rbf':{
        'C':np.arange(2,50)
    }
}

rec1, dfresult1 = GridSearchBP(models, params, dat)
# Out:
# For LR cross validation F1 score is 0.6856
# Parameters are {'C': 0.30000000000000004}.
# Runtime = 0.29131412506103516
# For SVM_linear cross validation F1 score is 0.6868
# Parameters are {'C': 6}.
# Runtime = 416.73961114883423
# For DecisionTree cross validation F1 score is 0.9083
# Parameters are {'max_depth': 18}.
# Runtime = 0.9634337425231934
# For RandomForest cross validation F1 score is 0.9573
# Parameters are {'max_depth': 19, 'n_estimators': 92}.
# Runtime = 988.3213334083557
# For AdaBoost cross validation F1 score is 0.8867
# Parameters are {'learning_rate': 0.9, 'n_estimators': 195}.
# Runtime = 1157.764374256134
# For XGBoost cross validation F1 score is 0.9536
# Parameters are {'learning_rate': 0.30000000000000004, 'max_depth': 8, 'n_estimators': 39}.
# Runtime = 1179.825395822525
# For SVM_rbf cross validation F1 score is 0.9002
# Parameters are {'C': 49}.
# Runtime = 147.9858374595642

# %%
#Testing of feature selection with auto setting and best parameters from above.

#data=df_list[0]
fsrec1={}

models_2 = {
    'LR':LR(C=0.4),
    'SVM_linear':SVC(kernel='linear',C=14),
    'DecisionTree':DTC(criterion='entropy',max_depth=14),
    'RandomForest':RFC(criterion='entropy',max_depth=18,n_estimators=78),
    'AdaBoost':ABC(learning_rate=0.6,n_estimators=196),
    'XGBoost':XGBC(tree_method='gpu_hist',learning_rate=0.3,max_depth=9,n_estimators=34),
    'SVM_rbf':SVC(kernel='rbf',C=19)
    }

for model in models_2:
    feature_selection = SFS(
        models_2[model], n_features_to_select='auto', direction="forward", n_jobs=-1
    ).fit(d4[0], d4[1])
    
    fsrec1[model] = feature_selection
    print(model, feature_selection.n_features_to_select_, d4[0].columns[feature_selection.support_])
# Out:
# LR 4 Index(['sofa_cns', 'charlson_comorbidity_index', 'lactate_max', 'ph_max'], dtype='object')
# SVM_linear 4 Index(['age', 'sofa_cns', 'charlson_comorbidity_index', 'ph_max'], dtype='object')
# DecisionTree 4 Index(['sofa_cardiovascular', 'sofa_cns', 'charlson_comorbidity_index',
#        'lactate_min'],
#       dtype='object')
# RandomForest 4 Index(['charlson_comorbidity_index', 'lactate_max', 'ph_min', 'ph_max'], dtype='object')
# AdaBoost 4 Index(['age', 'sofa_cardiovascular', 'charlson_comorbidity_index',
#        'lactate_min'],
#       dtype='object')
# XGBoost 4 Index(['sofa_cns', 'charlson_comorbidity_index', 'lactate_min', 'ph_max'], dtype='object')
# SVM_rbf 4 Index(['age', 'sofa_cardiovascular', 'sofa_cns', 'ph_min'], dtype='object')

# %%
#Creating a function for feature selection and fitting of best hyperparameters

def FeatureSelect_BestParams(models, models2, params, data, n_features):
    fsrec = {}
    bprec = {}
    dfresult = pd.concat([data[2],data[3]],axis=1)
    stratifiedCV = StratifiedKFold(n_splits=5)
    
    for model in models2:
        st = time.time()
        feature_selection = SFS(
            models2[model], n_features_to_select=n_features, direction="forward", n_jobs=-1
        ).fit(data[0], data[1])

        fsrec[model] = feature_selection
        print(model, feature_selection.n_features_to_select_, data[0].columns[feature_selection.support_])

        X = data[0].loc[:,list(data[0].columns[feature_selection.support_])]
        X_test = data[2].loc[:,list(data[0].columns[feature_selection.support_])]

        BestParams = GridSearchCV(
            models[model],
            param_grid = params[model],
            scoring='f1',
            n_jobs=-1
        )
        BestParams.fit(X,data[1])
        dfresult[model] = BestParams.predict(X_test)
        bprec[model] = BestParams
        et = time.time()
        print('For {} cross validation F1 score is {:.4f}'.format(model,BestParams.best_score_))
        print(f'Best parameters are {BestParams.best_params_}.')
        print(f'Runtime = {et-st}')
    return (fsrec, bprec, dfresult)

# %%
#Training and evaluating models with 10 features
data=d4

models = {
    'LR':LR(),
    'SVM_linear':SVC(kernel='linear'),
    'DecisionTree':DTC(criterion='entropy'),
    'RandomForest':RFC(criterion='entropy'),
    'AdaBoost':ABC(),
    'XGBoost':XGBC(tree_method='gpu_hist'),
    'SVM_rbf':SVC(kernel='rbf')
}

params = {
    'LR':{
        'C':np.arange(0.1,1,0.1)
    },
    'SVM_linear':{
        'C':np.arange(2,40)
    },
    'DecisionTree':{
        'max_depth':np.arange(1,20)
    },
    'RandomForest':{
        'n_estimators':np.arange(50,100),
        'max_depth':np.arange(1,20)
    },
    'AdaBoost':{
        'n_estimators':np.arange(100,200),
        'learning_rate':np.arange(0.1,1,0.1)
    },
    'XGBoost':{
        'n_estimators':np.arange(2,40),
        'max_depth':np.arange(2,10),
        'learning_rate':np.arange(0.1,1,0.1)
    },
    'SVM_rbf':{
        'C':np.arange(2,50)
    }
}

fs_rec1_10, bp_rec1_10, dfresult1_10 = FeatureSelect_BestParams(models, models_2, params, data, 5)
# Out:
# LR 5 Index(['age', 'sofa_cns', 'charlson_comorbidity_index', 'lactate_max',
#        'ph_max'],
#       dtype='object')
# For LR cross validation F1 score is 0.6761
# Best parameters are {'C': 0.6}.
# Runtime = 1.331385612487793
# SVM_linear 5 Index(['age', 'sofa_respiration', 'sofa_cns', 'charlson_comorbidity_index',
#        'ph_max'],
#       dtype='object')
# C:\Users\leow_\anaconda3\lib\site-packages\joblib\externals\loky\process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# For SVM_linear cross validation F1 score is 0.6780
# Best parameters are {'C': 5}.
# Runtime = 578.5779943466187
# DecisionTree 5 Index(['age', 'sofa_cardiovascular', 'sofa_cns', 'charlson_comorbidity_index',
#        'lactate_min'],
#       dtype='object')
# For DecisionTree cross validation F1 score is 0.9085
# Best parameters are {'max_depth': 19}.
# Runtime = 2.266160011291504
# RandomForest 5 Index(['sofa_cardiovascular', 'charlson_comorbidity_index', 'lactate_min',
#        'ph_min', 'ph_max'],
#       dtype='object')
# For RandomForest cross validation F1 score is 0.9478
# Best parameters are {'max_depth': 19, 'n_estimators': 94}.
# Runtime = 743.2536804676056
# AdaBoost 5 Index(['age', 'sofa_cardiovascular', 'sofa_cns', 'charlson_comorbidity_index',
#        'lactate_min'],
#       dtype='object')
# For AdaBoost cross validation F1 score is 0.8929
# Best parameters are {'learning_rate': 0.9, 'n_estimators': 194}.
# Runtime = 898.243896484375
# XGBoost 5 Index(['age', 'sofa_cns', 'charlson_comorbidity_index', 'lactate_min',
#        'ph_max'],
#       dtype='object')
# For XGBoost cross validation F1 score is 0.9484
# Best parameters are {'learning_rate': 0.30000000000000004, 'max_depth': 9, 'n_estimators': 39}.
# Runtime = 1191.1770310401917
# SVM_rbf 5 Index(['age', 'sofa_cardiovascular', 'sofa_cns', 'ph_min', 'ph_max'], dtype='object')
# For SVM_rbf cross validation F1 score is 0.8003
# Best parameters are {'C': 49}.
# Runtime = 418.1615889072418

# %%
ViewResult(dfresult1_10, models)
# Out:
#  Contingency Table for LR:
# Pred   False  True
# Label
# False   1383   516
# True      49    81
# F1 Score: 0.22283356258596976
#
#  Contingency Table for SVM_linear:
# Pred   False  True
# Label
# False   1415   484
# True      51    79
# F1 Score: 0.22799422799422803
#
#  Contingency Table for DecisionTree:
# Pred   False  True
# Label
# False   1748   151
# True      98    32
# F1 Score: 0.20447284345047925
#
#  Contingency Table for RandomForest:
# Pred   False  True
# Label
# False   1860    39
# True     122     8
# F1 Score: 0.09039548022598871
#
#  Contingency Table for AdaBoost:
# Pred   False  True
# Label
# False   1697   202
# True      86    44
# F1 Score: 0.23404255319148937
#
#  Contingency Table for XGBoost:
# Pred      0   1
# Label
# False  1860  39
# True    116  14
# F1 Score: 0.15300546448087432
#
#  Contingency Table for SVM_rbf:
# Pred   False  True
# Label
# False   1487   412
# True      71    59
# F1 Score: 0.19633943427620631

# %%
#Cross-validation f1 score of models is significantly higher than f1 score on test data. 
#There could be possible overfitting.
#Training and testing for 5 features instead to try reduce overfitting.

data=d4

params = {
    'LR':{
        'C':np.arange(0.1,1,0.1)
    },
    'SVM_linear':{
        'C':np.arange(2,40)
    },
    'DecisionTree':{
        'max_depth':np.arange(1,30) 
        #increase from 20 as the best parameter of the previous run (18) was close to the right boundary
    },
    'RandomForest':{
        'n_estimators':np.arange(50,100),
        'max_depth':np.arange(1,30)
        #increase from 20 as the best parameter of the previous run (18) was close to the right boundary
    },
    'AdaBoost':{
        'n_estimators':np.arange(100,200),
        'learning_rate':np.arange(0.1,1,0.1)
    },
    'XGBoost':{
        'n_estimators':np.arange(2,50), 
        #increase from the previous 40 as best parameter of the previous run (39) was at the right boundary
        'max_depth':np.arange(2,10),
        'learning_rate':np.arange(0.1,1,0.1)
    },
    'SVM_rbf':{
        'C':np.arange(2,50)
    }
}

fs_rec1_5, bp_rec1_5, dfresult1_5 = FeatureSelect_BestParams(models, models_2, params, data, 5)

# %%
ViewResult(dfresult1_5, models)

# %%
data=d4

params = {
    'LR':{
        'C':np.arange(0.1,1,0.1)
    },
    'SVM_linear':{
        'C':np.arange(2,40)
    },
    'DecisionTree':{
        'max_depth':np.arange(1,30) 
        #increase from 20 as the best parameter of the previous run (18) was close to the right boundary
    },
    'RandomForest':{
        'n_estimators':np.arange(50,100),
        'max_depth':np.arange(1,30)
        #increase from 20 as the best parameter of the previous run (18) was close to the right boundary
    },
    'AdaBoost':{
        'n_estimators':np.arange(100,200),
        'learning_rate':np.arange(0.1,1,0.1)
    },
    'XGBoost':{
        'n_estimators':np.arange(2,50), 
        #increase from the previous 40 as best parameter of the previous run (39) was at the right boundary
        'max_depth':np.arange(2,10),
        'learning_rate':np.arange(0.1,1,0.1)
    },
    'SVM_rbf':{
        'C':np.arange(2,50)
    }
}

fs_rec1_15, bp_rec1_15, dfresult1_15 = FeatureSelect_BestParams(models, models_2, params, data, 15)

# %%
ViewResult(dfresult1_15, models)

# %%
# Although the cross-validation f1 score is high, the f1 score of predicted outcomes is low.
# This shows that the models are overfitting. The result is the similar when we change the number of features.
# A possible reason could be the low number of data points resulting to 
# the model being learning from noise instead of actual patterns
# As such, testing on a bigger dataset, dataset 3, is explored below.

# %%
data3 = df_list[2]

#Based on the testing on dataset 1, SVM linear models seems to have similar performance to the Logistic Regression models.
#However, the time spent on feature selection and hyper parameter 
#tuning of a SVM_linear model is significantly higher than those of a Logistic Regression model.
#As such, SVM linear model is removed for now until a good performing Logistic Regression model can be achieved.
#Random Forest and Adaboost are removed due to time constriants.

models_data3 = {
    'LR':LR(),
    'DecisionTree':DTC(criterion='entropy'),
    'XGBoost':XGBC(tree_method='gpu_hist'),
    'SVM_rbf':SVC(kernel='rbf')
    }

params_data3 = {
    'LR':{
        'C':np.arange(0.1,2,0.1)
    },
    'DecisionTree':{
        'max_depth':np.arange(1,40)
    },

    'XGBoost':{
        'n_estimators':np.arange(2,50), 
        'max_depth':np.arange(2,10),
        'learning_rate':np.arange(0.1,1,0.1)
    },
    'SVM_rbf':{
        'C':np.arange(1,102,10)
    }
}

rec3, dfresult3 = GridSearchBP(models_data3, params_data3, data3)
# Out:
# For LR cross validation F1 score is 0.6938
# Parameters are {'C': 0.4}.
# Runtime = 5.159177541732788
# For DecisionTree cross validation F1 score is 0.9468
# Parameters are {'max_depth': 33}.
# Runtime = 16.87995719909668
# [02:02:02] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "tree_model" } are not used.
#
# For XGBoost cross validation F1 score is 0.9752
# Parameters are {'learning_rate': 0.4, 'max_depth': 9, 'n_estimators': 47}.
# Runtime = 4881.3133800029755

# %%
data3 = df_list[2]

params_data3 = {
    'LR':{
        'C':np.arange(0.1,2,0.1)
    },
    'DecisionTree':{
        'max_depth':np.arange(1,40)
    },
    'XGBoost':{
        'n_estimators':np.arange(2,50), 
        'max_depth':np.arange(2,10),
        'learning_rate':np.arange(0.1,1,0.1)
    },
    'SVM_rbf':{
        'C':np.arange(1,102,10)
    }
}

models2_data3 = {
    'LR':LR(C=0.4),
    'DecisionTree':DTC(criterion='entropy',max_depth=33),
    'XGBoost':XGBC(learning_rate=0.4, max_depth=9,n_estimators=47),
    'SVM_rbf':SVC(kernel='rbf',C=51)
    }


fsrec3_10, bprec3_10, dfresult3_10 = FeatureSelect_BestParams(models_data3, models2_data3, params_data3, data3, 10)
# Out:
# LR 10 Index(['heart_rate_mean', 'sbp_min', 'dbp_min', 'temperature_min', 'wbc_max',
#        'hemoglobin_min', 'pt_min', 'pt_max', 'urineoutput', 'sofa_cns'],
#       dtype='object')
# For LR cross validation F1 score is 0.7046
# Parameters are {'C': 0.1}.
# DecisionTree 10 Index(['age', 'heart_rate_max', 'mbp_max', 'mbp_mean', 'wbc_min',
#        'creatinine_min', 'creatinine_max', 'pt_max', 'sofa_coagulation',
#        'sofa_renal'],
#       dtype='object')
# For DecisionTree cross validation F1 score is 0.9504
# Parameters are {'max_depth': 27}.

# %%
data = df_list[1]

rec2, dfresult2 = GridSearchBP(models_data3, models2_data3, params_data3, data3, 10)
# Out:
# For LR cross validation F1 score is 0.6944
# Parameters are {'C': 1.0}.
# For DecisionTree cross validation F1 score is 0.9221
# Parameters are {'max_depth': 32}.
# For RandomForest cross validation F1 score is 0.9808
# Parameters are {'max_depth': 80, 'n_estimators': 200}.
# For XGBoost cross validation F1 score is 0.9590
# Parameters are {'learning_rate': 0.30000000000000004, 'max_depth': 9, 'n_estimators': 35}.
# For SVM_rbf cross validation F1 score is 0.9718
# Parameters are {'C': 51}.
